# %%
import pandas as pd

# %%
membros = list(range(1,10))
dfs=[]
for membro in membros:
    df = pd.read_csv('/media/lucasdmarten/HD/DADOS_TCC/RESULTADOS/CASO2/MEMBRO{}/c2.m{}.csv'.format(membro,membro))
    df['membro'] = membro
    dfs.append(df)
dfinal = pd.concat(dfs)

# %%
dfinal.to_csv('data_ensemble.c2.csv', index_label='id')

# %%
dfinal[dfinal['membro']==1]
# Out:
#                    times         T2         R2        TD2       PSFC  \
# 0    2018-09-22 18:00:00  302.11163  65.894140  21.762701  974.74744
# 1    2018-09-22 18:10:30  302.21765  63.263500  21.214400  974.58610
# 2    2018-09-22 18:21:00  302.32790  61.560287  20.884703  975.17065
# 3    2018-09-22 18:30:00  302.42610  60.630890  20.735239  975.10600
# 4    2018-09-22 18:40:30  302.42697  60.100880  20.597170  974.81494
# ..                   ...        ...        ...        ...        ...
# 320  2018-09-24 23:21:00  291.33224  67.786120  12.040693  981.69070
# 321  2018-09-24 23:30:00  291.39612  66.616040  11.840853  981.60876
# 322  2018-09-24 23:40:30  291.56192  65.141500  11.663320  981.84750
# 323  2018-09-24 23:51:00  291.58307  64.392240  11.510756  982.07960
# 324  2018-09-25 00:00:00  291.55300  64.014710  11.394830  982.18520
#
#        wspd10      wdir10    wspd67      wdir65     wspd88    wspd108  \
# ...
