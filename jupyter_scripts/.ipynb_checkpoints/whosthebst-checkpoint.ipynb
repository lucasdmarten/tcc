# %%
import numpy as np
import glob
import os
import pandas as pd
import datetime
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader
import cartopy.feature as cfeature
from cartopy import config
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import ShapelyFeature
from sklearn.metrics import mean_absolute_error,mean_squared_error
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt

# %%
pred = pd.read_csv('/media/lucasdmarten/HD/DADOS_TCC/RESULTADOS/CASO1/MEMBRO1/c1.m1.csv',usecols=[0,5,6,7,8,9,10,11])
pred = pred[36:-1]
obs = pd.read_csv('/media/lucasdmarten/HD/backup/projetos/tcc/tcc/data/ecc1_.csv',usecols=[0,3,4,5,6,10,12,16,18])
obs = obs[(obs.data>'2018-05-23') & (obs.data<'2018-05-25')]

# %%
# predictions
p_wspd_wdir_10 = pred.wspd10 ,pred.wdir10.astype('float').to_list()
p_wspd_wdir_bottom = pred.wspd67 ,pred.wdir65.astype('float').to_list()
p_wspd_wdir_top = pred.wspd108 ,pred.wdir106.astype('float').to_list()
p_wspd_mid = pred.wspd88.astype('float').to_list()

# %%
# observations
# Out:
# [7.206808000714631,
#  7.150333820597794,
#  7.09557773330411,
#  7.045979364764396,
#  7.001347079988103,
#  6.957687403957975,
#  6.937319187725023,
#  6.935764383615393,
#  6.9277342652743625,
#  6.905596012804137,
#  6.865093175098536,
#  6.823134134265832,
#  6.7820059670968345,
#  6.707041633571662,
#  6.597061542217285,
#  6.501899349927188,
#  6.397182650033443,
#  6.30441921930217,
#  6.220420603413582,
#  6.115278052992313,
#  6.017533598350957,
#  5.9435086022176105,
#  5.869374030835414,
#  5.828359376320182,
#  5.815767860346142,
#  5.821079213390731,
#  5.814391770526947,
#  5.798020986746747,
#  5.770066470700469,
#  5.734840613730293,
#  5.696041553303384,
#  5.623508028360346,
#  5.545265751066773,
#  5.497805507798035,
#  5.449111663863606,
#  5.3947374607032215,
#  5.349876878388121,
#  5.292875211300131,
#  5.227778518350356,
#  5.168197292137295,
#  5.095343892554155,
#  5.033526208775501,
#  4.985142812522799,
#  4.917673705522628,
#  4.838327881602192,
# ...
