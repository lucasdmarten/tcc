# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
d = pd.read_csv('../tcc/data/ecc1_.csv')
dCaso1 = d[(d.data>'2018-05-23') & (d.data<'2018-05-25')]
dCaso1.index=dCaso1.data
predict = pd.read_csv('./data_ensemble.c1.csv')
predict = predict[(predict['times']>='2018-05-23')&(predict['times']<'2018-05-25')]
predict.index=pd.to_datetime(predict.times )
# preparar dado para vizualizar em boxplot, considerando cada intervalo de 3 hras
p1=[]
p2=[]
p3=[]
p4=[]
p5=[]
p6=[]
p7=[]
p8=[]
p9=[]
box=[]
datas=[]
for time in list_date[:-1]:
    time_i, time_f = time, time+datetime.timedelta(hours=3)
    df = predict.loc[str(time_i):str(time_f)]
    p1.append(list(map(float,df[df['membro']==1].wspd108.astype('float').to_list())))    
    p2.append(list(map(float,df[df['membro']==2].wspd108.astype('float').to_list())))
    p3.append(list(map(float,df[df['membro']==3].wspd108.astype('float').to_list())))
    p4.append(list(map(float,df[df['membro']==4].wspd108.astype('float').to_list())))
    p5.append(list(map(float,df[df['membro']==5].wspd108.astype('float').to_list())))
    p6.append(list(map(float,df[df['membro']==6].wspd108.astype('float').to_list())))
    p7.append(list(map(float,df[df['membro']==7].wspd108.astype('float').to_list())))
    p8.append(list(map(float,df[df['membro']==8].wspd108.astype('float').to_list())))
    p9.append(list(map(float,df[df['membro']==9].wspd108.astype('float').to_list())))

    
    box.append(list(map(float,dCaso1.loc[str(time_i):str(time_f)].iloc[:,6].to_list())))
    
    datas.append(list(map(str,dCaso1.loc[str(time_i):str(time_f)].iloc[:,0].to_list()))[-1])
    
newdates=[]
for i in range(len(datas)):
    date_obj = datetime.datetime.strptime(datas[i], '%Y-%m-%d %H:%M:%S')
    newdates.append('{:02d}/{:02d} - {:02d}hrs'.format(date_obj.day,date_obj.month,date_obj.hour))
media_p1=[]
media_p2=[]
media_p3=[]
media_p4=[]
media_p5=[]
media_p6=[]
media_p7=[]
media_p8=[]
media_p9=[]
media_obs=[]
for i in range(0,len(box)):
    media_obs.append(np.mean(box[i]))
    media_p1.append(np.mean(p1[i]))
    media_p2.append(np.mean(p2[i]))
    media_p3.append(np.mean(p3[i]))
    media_p4.append(np.mean(p4[i]))
    media_p5.append(np.mean(p5[i]))
    media_p6.append(np.mean(p6[i]))
    media_p7.append(np.mean(p7[i]))
    media_p8.append(np.mean(p8[i]))
    media_p9.append(np.mean(p9[i]))
# Out:
# 2018-05-23 00:00:00
# 2018-05-23 03:00:00
# 2018-05-23 03:00:00
# 2018-05-23 06:00:00
# 2018-05-23 06:00:00
# 2018-05-23 09:00:00
# 2018-05-23 09:00:00
# 2018-05-23 12:00:00
# 2018-05-23 12:00:00
# 2018-05-23 15:00:00
# 2018-05-23 15:00:00
# 2018-05-23 18:00:00
# 2018-05-23 18:00:00
# 2018-05-23 21:00:00
# 2018-05-23 21:00:00
# 2018-05-24 00:00:00
# 2018-05-24 00:00:00
# 2018-05-24 03:00:00
# 2018-05-24 03:00:00
# 2018-05-24 06:00:00
# 2018-05-24 06:00:00
# 2018-05-24 09:00:00
# 2018-05-24 09:00:00
# 2018-05-24 12:00:00
# 2018-05-24 12:00:00
# 2018-05-24 15:00:00
# 2018-05-24 15:00:00
# 2018-05-24 18:00:00
# 2018-05-24 18:00:00
# 2018-05-24 21:00:00
# 2018-05-24 21:00:00
# 2018-05-25 00:00:00

# %%
d = pd.read_csv('../tcc/data/ecc1_.csv')

# %%
dCaso1 = d[(d.data>'2018-05-23') & (d.data<'2018-05-25')]
dCaso1.index=dCaso1.data
dCaso2 = d[(d.data>'2018-09-23') & (d.data<'2018-09-25')]
dCaso2.index=dCaso2.data
dCaso2[dCaso2=='np.nan'] = np.nan
# Out:
# <ipython-input-113-3124f8ffd8a7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dCaso2[dCaso2=='np.nan'] = np.nan
# /home/lucasdmarten/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
predict = pd.read_csv('./data_ensemble.c1.csv')
predict = predict[(predict['times']>='2018-05-23')&(predict['times']<'2018-05-25')]
predict[predict['membro']==1].iloc[0:18]
# Out:
#     id                times         T2         R2       TD2       PSFC  \
# 36  36  2018-05-23 00:00:00  279.62448  82.270240  3.610282  988.83930
# 37  37  2018-05-23 00:10:30  279.52588  82.450850  3.545201  988.95710
# 38  38  2018-05-23 00:21:00  279.43295  82.601295  3.480406  989.11020
# 39  39  2018-05-23 00:30:00  279.36176  82.737030  3.434182  989.19250
# 40  40  2018-05-23 00:40:30  279.26724  82.866790  3.364177  989.24720
# 41  41  2018-05-23 00:51:00  279.18040  82.940384  3.292062  989.32654
# 42  42  2018-05-23 01:00:00  279.12140  83.036026  3.250781  989.29220
# 43  43  2018-05-23 01:10:30  279.04920  83.107680  3.192540  989.18920
# 44  44  2018-05-23 01:21:00  278.97418  83.106510  3.119257  989.19440
# 45  45  2018-05-23 01:30:00  278.92180  83.104840  3.067955  989.23096
# 46  46  2018-05-23 01:40:30  278.82910  83.023735  2.963943  989.28467
# 47  47  2018-05-23 01:51:00  278.74182  82.905260  2.858917  989.32960
# 48  48  2018-05-23 02:00:00  278.69247  82.809100  2.794607  989.36725
# 49  49  2018-05-23 02:10:30  278.61550  82.571240  2.679423  989.45905
# 50  50  2018-05-23 02:21:00  278.52478  82.329025  2.550040  989.56080
# 51  51  2018-05-23 02:30:00  278.47006  82.108890  2.459403  989.66766
# 52  52  2018-05-23 02:40:30  278.39825  81.831290  2.342288  989.77826
# 53  53  2018-05-23 02:51:00  278.33588  81.591140  2.240639  989.78150
#
#       wspd10     wdir10    wspd67      wdir65    wspd88   wspd108     wdir106  \
# 36  3.465512  232.83460  6.972328  224.564539  7.206808  7.345418  220.801363
# 37  3.452837  232.25392  6.924537  223.551012  7.150334  7.281176  219.681601
# 38  3.440501  231.64702  6.877312  222.424868  7.095578  7.219474  218.440860
# 39  3.426627  230.97472  6.833281  221.303609  7.045979  7.164559  217.238615
# 40  3.415855  230.06125  6.796067  219.862178  7.001347  7.112888  215.721205
# 41  3.407354  229.22473  6.762046  218.428266  6.957687  7.060215  214.249536
# 42  3.403567  228.31148  6.751337  217.080546  6.937319  7.030920  212.923484
# 43  3.412575  227.20586  6.763738  215.562073  6.935764  7.016527  211.497192
# 44  3.417009  226.09856  6.770985  214.108907  6.927734  6.994007  210.193416
# 45  3.412432  225.14667  6.764545  212.903243  6.905596  6.957803  209.158471
# 46  3.407057  224.03778  6.746923  211.549681  6.865093  6.898310  208.068265
# 47  3.405311  222.73802  6.732623  210.164146  6.823134  6.835513  207.008134
# 48  3.404758  221.61993  6.718076  209.083726  6.782006  6.775855  206.234199
# 49  3.403034  220.48125  6.674232  208.009367  6.707042  6.680429  205.507882
# 50  3.390769  219.64642  6.594223  207.137340  6.597062  6.551646  204.960206
# 51  3.382076  219.07720  6.522673  206.533325  6.501899  6.442346  204.596350
# 52  3.378181  218.50768  6.442507  205.908639  6.397183  6.323424  204.211582
# 53  3.379300  218.09435  6.369698  205.457862  6.304419  6.219321  203.934986
#
#     membro
# 36       1
# 37       1
# 38       1
# 39       1
# 40       1
# 41       1
# 42       1
# 43       1
# 44       1
# 45       1
# 46       1
# 47       1
# 48       1
# 49       1
# 50       1
# 51       1
# 52       1
# 53       1

# %%
# criar lista datetime
di = datetime.datetime(2018,9,23,0)
df = datetime.datetime(2018,9,25,0)
dates = []
while di < df:
    dates.append(di)
    di += datetime.timedelta(hours=3)


# str to obj_time
def converttoobj(time_str):
    time_obj = datetime.datetime.strptime(time_str, '%Y-%m-%d %H:%M:%S')
    return time_obj

# %%
# preparar dado para vizualizar em boxplot, considerando cada intervalo de 3 hras
box=[]
p1=[]
p2=[]
p3=[]
p4=[]
p5=[]
p6=[]
p7=[]
p8=[]
p9=[]
datas=[]
i=0
while i < 288:
    p1.append(list(map(float,predict[predict.membro==1].wspd108.iloc[i:i+18].to_list())))    
    p2.append(list(map(float,predict[predict.membro==2].wspd108.iloc[i:i+18].to_list())))
    p3.append(list(map(float,predict[predict.membro==3].wspd108.iloc[i:i+18].to_list())))
    p4.append(list(map(float,predict[predict.membro==4].wspd108.iloc[i:i+18].to_list())))
    p5.append(list(map(float,predict[predict.membro==5].wspd108.iloc[i:i+18].to_list())))
    p6.append(list(map(float,predict[predict.membro==6].wspd108.iloc[i:i+18].to_list())))
    p7.append(list(map(float,predict[predict.membro==7].wspd108.iloc[i:i+18].to_list())))
    p8.append(list(map(float,predict[predict.membro==8].wspd108.iloc[i:i+18].to_list())))
    p9.append(list(map(float,predict[predict.membro==9].wspd108.iloc[i:i+18].to_list())))

    
    box.append(list(map(float,dCaso1.iloc[i:i+18,6].to_list())))
    
    datas.append(list(map(str,dCaso1.iloc[i:i+18,0].to_list()))[-1])
    
    i+=18
newdates=[]
for i in range(len(datas)):
    date_obj = datetime.datetime.strptime(datas[i], '%Y-%m-%d %H:%M:%S')
    newdates.append('{:02d}/{:02d} - {:02d}hrs'.format(date_obj.day,date_obj.month,date_obj.hour))
newdates
# Out:
# ['23/05 - 02hrs',
#  '23/05 - 05hrs',
#  '23/05 - 08hrs',
#  '23/05 - 11hrs',
#  '23/05 - 14hrs',
#  '23/05 - 17hrs',
#  '23/05 - 20hrs',
#  '23/05 - 23hrs',
#  '24/05 - 02hrs',
#  '24/05 - 05hrs',
#  '24/05 - 08hrs',
#  '24/05 - 11hrs',
#  '24/05 - 14hrs',
#  '24/05 - 17hrs',
#  '24/05 - 20hrs',
#  '24/05 - 23hrs']

# %%
list_date = pd.date_range(datetime.datetime(2018,5,23,0),datetime.datetime(2018,5,25,0),freq='3H')
predict.index = pd.to_datetime(predict.index)
# Out:
#                      id                times         T2         R2       TD2  \
# times
# 2018-05-23 00:00:00  36  2018-05-23 00:00:00  279.62448  82.270240  3.610282
# 2018-05-23 00:10:30  37  2018-05-23 00:10:30  279.52588  82.450850  3.545201
# 2018-05-23 00:21:00  38  2018-05-23 00:21:00  279.43295  82.601295  3.480406
# 2018-05-23 00:30:00  39  2018-05-23 00:30:00  279.36176  82.737030  3.434182
# 2018-05-23 00:40:30  40  2018-05-23 00:40:30  279.26724  82.866790  3.364177
# ...                  ..                  ...        ...        ...       ...
# 2018-05-23 02:00:00  48  2018-05-23 02:00:00  278.14963  88.557390  3.204426
# 2018-05-23 02:10:30  49  2018-05-23 02:10:30  278.07382  88.375460  3.101203
# 2018-05-23 02:21:00  50  2018-05-23 02:21:00  277.99518  88.170110  2.991452
# 2018-05-23 02:30:00  51  2018-05-23 02:30:00  277.94348  88.019810  2.916856
# 2018-05-23 02:40:30  52  2018-05-23 02:40:30  277.87830  87.840100  2.824330
#
#                          PSFC    wspd10     wdir10    wspd67      wdir65  \
# times
# 2018-05-23 00:00:00  988.8393  3.465512  232.83460  6.972328  224.564539
# 2018-05-23 00:10:30  988.9571  3.452837  232.25392  6.924537  223.551012
# 2018-05-23 00:21:00  989.1102  3.440501  231.64702  6.877312  222.424868
# 2018-05-23 00:30:00  989.1925  3.426627  230.97472  6.833281  221.303609
# 2018-05-23 00:40:30  989.2472  3.415855  230.06125  6.796067  219.862178
# ...                       ...       ...        ...       ...         ...
# 2018-05-23 02:00:00  989.4084  3.218010  223.90787  6.811624  210.249383
# 2018-05-23 02:10:30  989.5048  3.230887  223.02615  6.743238  209.414638
# 2018-05-23 02:21:00  989.6076  3.246538  222.43372  6.655994  208.682474
# 2018-05-23 02:30:00  989.7137  3.227986  221.97970  6.593826  208.107353
# 2018-05-23 02:40:30  989.8239  3.198434  221.55066  6.534659  207.480186
#
#                        wspd88   wspd108     wdir106  membro
# times
# 2018-05-23 00:00:00  7.206808  7.345418  220.801363       1
# 2018-05-23 00:10:30  7.150334  7.281176  219.681601       1
# 2018-05-23 00:21:00  7.095578  7.219474  218.440860       1
# 2018-05-23 00:30:00  7.045979  7.164559  217.238615       1
# 2018-05-23 00:40:30  7.001347  7.112888  215.721205       1
# ...                       ...       ...         ...     ...
# 2018-05-23 02:00:00  6.721628  6.655555  205.999362       9
# 2018-05-23 02:10:30  6.632785  6.552528  205.340845       9
# 2018-05-23 02:21:00  6.532996  6.437262  204.724523       9
# 2018-05-23 02:30:00  6.459319  6.350488  204.213665       9
# 2018-05-23 02:40:30  6.386092  6.262286  203.624832       9
#
# [153 rows x 14 columns]

# %%
list_date
# Out:
# DatetimeIndex(['2018-05-23 00:00:00', '2018-05-23 03:00:00',
#                '2018-05-23 06:00:00', '2018-05-23 09:00:00',
#                '2018-05-23 12:00:00', '2018-05-23 15:00:00',
#                '2018-05-23 18:00:00', '2018-05-23 21:00:00',
#                '2018-05-24 00:00:00', '2018-05-24 03:00:00',
#                '2018-05-24 06:00:00', '2018-05-24 09:00:00',
#                '2018-05-24 12:00:00', '2018-05-24 15:00:00',
#                '2018-05-24 18:00:00', '2018-05-24 21:00:00',
#                '2018-05-25 00:00:00'],
#               dtype='datetime64[ns]', freq='3H')

# %%
p1=[]
p2=[]
p3=[]
p4=[]
p5=[]
p6=[]
p7=[]
p8=[]
p9=[]
box=[]
datas=[]
for time in list_date[:-2]:
    time_i, time_f = time, time+datetime.timedelta(hours=3)
    print(time_i)
    print(time_f)
    df = predict.loc[str(time_i):str(time_f)]
    p1.append(list(map(float,df[df['membro']==1].wspd108.astype('float').to_list())))    
    p2.append(list(map(float,df[df['membro']==2].wspd108.astype('float').to_list())))
    p3.append(list(map(float,df[df['membro']==3].wspd108.astype('float').to_list())))
    p4.append(list(map(float,df[df['membro']==4].wspd108.astype('float').to_list())))
    p5.append(list(map(float,df[df['membro']==5].wspd108.astype('float').to_list())))
    p6.append(list(map(float,df[df['membro']==6].wspd108.astype('float').to_list())))
    p7.append(list(map(float,df[df['membro']==7].wspd108.astype('float').to_list())))
    p8.append(list(map(float,df[df['membro']==8].wspd108.astype('float').to_list())))
    p9.append(list(map(float,df[df['membro']==9].wspd108.astype('float').to_list())))

    
    box.append(list(map(float,dCaso1.loc[str(time_i):str(time_f)].iloc[:,6].to_list())))
    
    datas.append(list(map(str,dCaso1.loc[str(time_i):str(time_f)].iloc[:,0].to_list()))[-1])
# Out:
# 2018-05-23 00:00:00
# 2018-05-23 03:00:00
# 2018-05-23 03:00:00
# 2018-05-23 06:00:00
# 2018-05-23 06:00:00
# 2018-05-23 09:00:00
# 2018-05-23 09:00:00
# 2018-05-23 12:00:00
# 2018-05-23 12:00:00
# 2018-05-23 15:00:00
# 2018-05-23 15:00:00
# 2018-05-23 18:00:00
# 2018-05-23 18:00:00
# 2018-05-23 21:00:00
# 2018-05-23 21:00:00
# 2018-05-24 00:00:00
# 2018-05-24 00:00:00
# 2018-05-24 03:00:00
# 2018-05-24 03:00:00
# 2018-05-24 06:00:00
# 2018-05-24 06:00:00
# 2018-05-24 09:00:00
# 2018-05-24 09:00:00
# 2018-05-24 12:00:00
# 2018-05-24 12:00:00
# 2018-05-24 15:00:00
# 2018-05-24 15:00:00
# 2018-05-24 18:00:00
# 2018-05-24 18:00:00
# 2018-05-24 21:00:00

# %%
dCaso1.loc[str(time_i):str(time_f)].iloc[:,0]
# Out:
# data
# 2018-05-24 18:00:00    2018-05-24 18:00:00
# 2018-05-24 18:10:00    2018-05-24 18:10:00
# 2018-05-24 18:20:00    2018-05-24 18:20:00
# 2018-05-24 18:30:00    2018-05-24 18:30:00
# 2018-05-24 18:40:00    2018-05-24 18:40:00
# 2018-05-24 18:50:00    2018-05-24 18:50:00
# 2018-05-24 19:00:00    2018-05-24 19:00:00
# 2018-05-24 19:10:00    2018-05-24 19:10:00
# 2018-05-24 19:20:00    2018-05-24 19:20:00
# 2018-05-24 19:30:00    2018-05-24 19:30:00
# 2018-05-24 19:40:00    2018-05-24 19:40:00
# 2018-05-24 19:50:00    2018-05-24 19:50:00
# 2018-05-24 20:00:00    2018-05-24 20:00:00
# 2018-05-24 20:10:00    2018-05-24 20:10:00
# 2018-05-24 20:20:00    2018-05-24 20:20:00
# 2018-05-24 20:30:00    2018-05-24 20:30:00
# 2018-05-24 20:40:00    2018-05-24 20:40:00
# 2018-05-24 20:50:00    2018-05-24 20:50:00
# 2018-05-24 21:00:00    2018-05-24 21:00:00
# Name: data, dtype: object

# %%
df[df.membro==1].loc[str(time_i):str(time_f)].index
# Out:
# DatetimeIndex(['2018-05-24 18:00:00', '2018-05-24 18:10:30',
#                '2018-05-24 18:21:00', '2018-05-24 18:30:00',
#                '2018-05-24 18:40:30', '2018-05-24 18:51:00',
#                '2018-05-24 19:00:00', '2018-05-24 19:10:30',
#                '2018-05-24 19:21:00', '2018-05-24 19:30:00',
#                '2018-05-24 19:40:30', '2018-05-24 19:51:00',
#                '2018-05-24 20:00:00', '2018-05-24 20:10:30',
#                '2018-05-24 20:21:00', '2018-05-24 20:30:00',
#                '2018-05-24 20:40:30', '2018-05-24 20:51:00',
#                '2018-05-24 21:00:00'],
#               dtype='datetime64[ns]', name='times', freq=None)

# %%
predict.loc[]
# Out:
#   File "<ipython-input-142-e363fe9372f3>", line 1
#     predict.loc[]
#                 ^
# SyntaxError: invalid syntax

# %%
print(
        'Variancia do período: {} \n'.format(np.var(dCaso1.iloc[:,6].astype('float').to_list()))   
)
print(
        'Desvio padrão do período: {} \n'.format(np.std(dCaso1.iloc[:,6].astype('float').to_list()))
)
print(
        'Média do período: {} \n'.format(np.mean(dCaso1.iloc[:,6].astype('float').to_list()))
)
# Out:
# Variancia do período: 2.6225711757330243
#
# Desvio padrão do período: 1.6194354496962897
#
# Média do período: 3.1936805555555554

# %%
np.mean(p1[0])
# Out:
# 6.844089641988266

# %%
media_p1=[]
media_p2=[]
media_p3=[]
media_p4=[]
media_p5=[]
media_p6=[]
media_p7=[]
media_p8=[]
media_p9=[]
media_obs=[]
for i in range(0,len(box)):
    media_obs.append(np.mean(box[i]))
    media_p1.append(np.mean(p1[i]))
    media_p2.append(np.mean(p2[i]))
    media_p3.append(np.mean(p3[i]))
    media_p4.append(np.mean(p4[i]))
    media_p5.append(np.mean(p5[i]))
    media_p6.append(np.mean(p6[i]))
    media_p7.append(np.mean(p7[i]))
    media_p8.append(np.mean(p8[i]))
    media_p9.append(np.mean(p9[i]))

# %%
plt.plot(media_obs)

# %%
fig = plt.figure(figsize =(20, 14))

bplot1 = plt.boxplot(x=box,vert=True,  # vertical box alignment
             patch_artist=True,
            labels=newdates[1:])  # will be used to label x-ticks

# plt.plot(media_p1,'--', label='Membro 1')
# plt.plot(media_p2,'--', label='Membro 2')
# plt.plot(media_p3,'--', label='Membro 3')
# plt.plot(media_p4,'--', label='Membro 4')
# plt.plot(media_p5,'--', label='Membro 5')
# plt.plot(media_p6,'--', label='Membro 6')
# plt.plot(media_p7,'--', label='Membro 7')
# plt.plot(media_p8,'--', label='Membro 8')
# plt.plot(media_p9,'--', label='Membro 9')
# plt.plot(media_obs,'--', label="OBS")
# plt.legend()


degrees = 70
plt.xticks(rotation=degrees)

# plt.savefig('boxplot2.png',dpi=300)
plt.show()

# %%
mean_ensemble=(np.array(media_p1)+np.array(media_p2)+np.array(media_p3)+np.array(media_p4)+np.array(media_p5)+np.array(media_p6)+np.array(media_p7)+np.array(media_p8)+np.array(media_p9))/9

# %%
newdates[:-1]
# Out:
# ['23/05 - 02hrs',
#  '23/05 - 05hrs',
#  '23/05 - 08hrs',
#  '23/05 - 11hrs',
#  '23/05 - 14hrs',
#  '23/05 - 17hrs',
#  '23/05 - 20hrs',
#  '23/05 - 23hrs',
#  '24/05 - 02hrs',
#  '24/05 - 05hrs',
#  '24/05 - 08hrs',
#  '24/05 - 11hrs',
#  '24/05 - 14hrs',
#  '24/05 - 17hrs',
#  '24/05 - 20hrs']

# %% [markdown]
# d

# %%
#fig = plt.figure(figsize =(20, 8))
fig, axs = plt.subplots(2,figsize =(20, 12))
axs[0].grid(True)
axs[0].plot(newdates[:-1],media_p1,'--', label='Membro 1')
axs[0].plot(media_p2,'--', label='Membro 2')
axs[0].plot(media_p3,'--', label='Membro 3')
axs[0].plot(media_p4,'--', label='Membro 4')
axs[0].plot(media_p5,'--', label='Membro 5')
axs[0].plot(media_p6,'--', label='Membro 6')
axs[0].plot(media_p7,'--', label='Membro 7')
axs[0].plot(media_p8,'--', label='Membro 8')
axs[0].plot(media_p9,'--', label='Membro 9')
axs[0].plot(media_obs, label="OBS")
axs[0].set_ylim(0,10)
#axs[0].set_xticks([])
axs[0].get_xaxis().set_visible(False)

axs[1].plot(newdates[1:],media_obs, label="Observado ECC1")
axs[1].plot(mean_ensemble, label="Média dos membros")
axs[1].set_ylim(0,10)
axs[1].grid(True)


axs[1].legend()

degrees = 70
plt.xticks(rotation=degrees)

plt.savefig('teste.png', dpi=300, facecolor='w', edgecolor='w',
         papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)

# plt.savefig('teste.png',dpi=300)
plt.show()
# Out:
# <ipython-input-244-00f8258bd1e3>:29: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('teste.png', dpi=300, facecolor='w', edgecolor='w',
# <ipython-input-244-00f8258bd1e3>:29: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('teste.png', dpi=300, facecolor='w', edgecolor='w',

# %%
newdates[1:]
