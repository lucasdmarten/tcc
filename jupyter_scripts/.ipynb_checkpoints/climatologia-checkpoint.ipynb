# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/media/lucasdmarten/HD/DADOS_TCC/dados_estacao/historicos/dados_A804_M_2001-11-21_2020-01-01.csv"
d = pd.read_csv(path,skiprows=9,delimiter=';').interpolate()
d.index = pd.to_datetime(d["Data Medicao"])

# %%
d.columns
# Out:
# Index(['Data Medicao', 'NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(número)',
#        'PRECIPITACAO TOTAL, MENSAL (AUT)(mm)',
#        'PRESSAO ATMOSFERICA, MEDIA MENSAL (AUT)(mB)',
#        'TEMPERATURA MEDIA, MENSAL (AUT)(°C)',
#        'VENTO, VELOCIDADE MAXIMA MENSAL (AUT)(m/s)',
#        'VENTO, VELOCIDADE MEDIA MENSAL (AUT)(m/s)', 'Unnamed: 7'],
#       dtype='object')

# %%
df = d.groupby(d.index.month).mean()
df.index = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
mean_wind_month=df["TEMPERATURA MEDIA, MENSAL (AUT)(°C)"].tolist()

# %%
fig = plt.figure(figsize =(20, 14))
# Creating plot
plt.plot(df.index,mean_wind_month)

plt.ylabel("Temperatura média mensal (hPa)", fontsize=25)
plt.yticks(fontsize=15)

plt.xlabel("Mês", fontsize=25)
plt.xticks(fontsize=15)

plt.grid(True)
plt.title("Temperatura média do vento estação A804 - Santana do Livramento",  fontsize=25)
plt.savefig('month_temperature_mean_A804.png',dpi=300)
plt.show()

# %%
df2 = df.groupby(df.index.month,0).mean()

# %%
df.index = pd.to_datetime(df.index)

# %%
df2['VENTO, VELOCIDADE MEDIA MENSAL (AUT)(m/s)'].plot()
# Out:
# <AxesSubplot:xlabel='Data Medicao'>

# %%
df2
# Out:
#               NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(número)  \
# Data Medicao
# 1                                                      8.478618
# 2                                                      9.697917
# 3                                                     10.001736
# 4                                                     10.027778
# 5                                                     12.442708
# 6                                                     12.218750
# 7                                                     10.383681
# 8                                                     10.381944
# 9                                                     11.482639
# 10                                                    11.333333
# 11                                                     8.016447
# 12                                                     8.348684
#
#               PRECIPITACAO TOTAL, MENSAL (AUT)(mm)  \
# Data Medicao
# 1                                       160.524004
# 2                                       161.081830
# 3                                       145.769804
# 4                                       155.224444
# 5                                       128.990196
# 6                                        97.452614
# 7                                       115.431699
# 8                                       120.220044
# 9                                       149.136166
# 10                                      180.177778
# 11                                      153.660131
# 12                                      155.812590
#
#               PRESSAO ATMOSFERICA, MEDIA MENSAL (AUT)(mB)  \
# Data Medicao
# 1                                              978.430283
# 2                                              978.478277
# 3                                              979.690309
# 4                                              981.177831
# 5                                              982.674325
# 6                                              983.023912
# 7                                              983.426298
# 8                                              983.358279
# 9                                              982.615660
# 10                                             980.449328
# 11                                             979.136115
# 12                                             978.165077
#
#               TEMPERATURA MEDIA, MENSAL (AUT)(°C)  \
# Data Medicao
# 1                                       22.774292
# 2                                       22.096197
# 3                                       20.684539
# 4                                       18.282965
# 5                                       15.128869
# 6                                       13.418155
# 7                                       12.764576
# 8                                       13.650200
# 9                                       15.071538
# 10                                      17.435004
# 11                                      19.798112
# 12                                      21.472874
#
#               VENTO, VELOCIDADE MAXIMA MENSAL (AUT)(m/s)  \
# Data Medicao
# 1                                              10.002029
# 2                                               9.075810
# 3                                               9.293924
# 4                                               9.197222
# 5                                               9.456076
# 6                                               9.414931
# 7                                              10.007118
# 8                                              10.865972
# 9                                              10.049653
# 10                                             10.175000
# 11                                             10.528125
# 12                                             10.158553
#
#               VENTO, VELOCIDADE MEDIA MENSAL (AUT)(m/s)  Unnamed: 7
# Data Medicao
# 1                                              2.971510         NaN
# 2                                              2.902196         NaN
# 3                                              2.852376         NaN
# 4                                              2.681956         NaN
# 5                                              2.833639         NaN
# 6                                              2.928071         NaN
# 7                                              3.065397         NaN
# 8                                              3.232218         NaN
# 9                                              3.290045         NaN
# 10                                             3.269589         NaN
# 11                                             3.083624         NaN
# 12                                             3.025150         NaN

# %%
plt.yticks?
