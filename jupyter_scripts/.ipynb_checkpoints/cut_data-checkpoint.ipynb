# %%
import numpy as np
from wrf import getvar, ALL_TIMES, interplevel, get_cartopy, to_np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import pandas as pd

# %%
wrfile = Dataset('/media/lucasdmarten/HD/DADOS_TCC/RESULTADOS/CASO1/MEMBRO1/wrfout_d01_2018-05-22_18:00:00')
geo = Dataset('/media/lucasdmarten/HD/wrf/domains/firstDomainPC/geo_em.d01.nc')

# %%
speed = getvar(wrfile,'wspd_wdir', timeidx=ALL_TIMES)[0,:,:,49,49]

# %%
topo = wrf.getvar(geo,'HGT_M')
speed_at100 = wrf.interplevel(speed, z, 108+topo)[:,49,49]
# Out:
# <xarray.DataArray 'wspd_wdir' (Time: 325, bottom_top: 39)>
# array([[ 3.7553954,  4.0007696,  4.245095 , ..., 42.73189  , 41.551624 ,
#         40.631294 ],
#        [ 3.9003258,  4.1363134,  4.2435975, ..., 42.619755 , 41.397884 ,
#         40.483944 ],
#        [ 3.8895726,  4.1343694,  4.2457895, ..., 42.496483 , 41.237167 ,
#         40.30387  ],
#        ...,
#        [ 2.0724251,  3.4464827,  3.7925112, ..., 23.465015 , 24.393448 ,
#         26.178423 ],
#        [ 2.1490119,  3.6020954,  3.9534495, ..., 23.340605 , 24.298971 ,
#         26.144423 ],
#        [ 2.2240663,  3.7477238,  4.1034274, ..., 23.236544 , 24.250166 ,
#         26.154955 ]], dtype=float32)
# Coordinates:
#     wspd_wdir  <U4 'wspd'
#     XLONG      float32 -55.68
#     XLAT       float32 -30.86
#     XTIME      (Time) float32 0.0 10.5 21.0 30.0 ... 3.22e+03 3.231e+03 3.24e+03
#   * Time       (Time) datetime64[ns] 2018-05-22T18:00:00 ... 2018-05-25
# Dimensions without coordinates: bottom_top
# ...

# %%
T2=list(getvar(wrfile,'T2', timeidx=ALL_TIMES)[:,49,49].values)
PSFC=list(getvar(wrfile,'PSFC', timeidx=ALL_TIMES)[:,49,49].values/10**2)
V10=list(getvar(wrfile,'V10', timeidx=ALL_TIMES)[:,49,49].values)
U10=list(getvar(wrfile,'U10', timeidx=ALL_TIMES)[:,49,49].values)
times=list(getvar(wrfile,'times', timeidx=ALL_TIMES)[:].values)

# %%
pd.DataFrame(
    {"T2":T2,"PSFC":PSFC,"U10":U10,"V10":V10}, index=times, dtype='int8'
)
# Out:
#                           T2     PSFC      U10      V10
# 2018-05-22 18:00:00  288.091  987.503  2.87561   2.0873
# 2018-05-22 18:10:30  287.978  987.211  2.77843  2.17601
# 2018-05-22 18:21:00  287.906  987.376  2.78129  2.13327
# 2018-05-22 18:30:00  287.944  987.484  2.81142  2.12083
# 2018-05-22 18:40:30  287.825  987.325   2.8558  2.13685
# ...                      ...      ...      ...      ...
# 2018-05-24 23:21:00  281.498  991.608 -1.27147  1.27866
# 2018-05-24 23:30:00  281.408  991.562 -1.30524  1.30364
# 2018-05-24 23:40:30  281.319  991.623 -1.36004  1.33368
# 2018-05-24 23:51:00  281.237  991.716 -1.42358  1.36906
# 2018-05-25 00:00:00  281.167  991.782 -1.48072  1.40621
#
# [325 rows x 4 columns]

# %%
getvar(wrfile,'T2', timeidx=ALL_TIMES)
# Out:
# <xarray.DataArray 'T2' (Time: 325, south_north: 99, west_east: 99)>
# array([[[288.80957, 288.583  , 288.30957, ..., 288.41992, 288.47467,
#          288.58704],
#         [288.9736 , 288.76846, 288.5807 , ..., 288.40607, 288.46265,
#          288.57077],
#         [289.079  , 288.8847 , 288.76523, ..., 288.42404, 288.48224,
#          288.58685],
#         ...,
#         [297.95068, 298.2165 , 298.30518, ..., 291.6675 , 291.7846 ,
#          292.25885],
#         [298.179  , 298.01715, 298.0854 , ..., 291.9905 , 292.23407,
#          292.8391 ],
#         [298.06342, 297.4895 , 297.56042, ..., 292.7417 , 292.77487,
#          292.86124]],
#
#        [[289.1911 , 289.02005, 288.64502, ..., 288.9478 , 289.03024,
#          289.1427 ],
#         [289.43393, 288.9899 , 288.79376, ..., 288.83594, 288.85138,
#          289.11157],
#         [289.15564, 288.5867 , 288.566  , ..., 288.87802, 288.8756 ,
#          289.15005],
# ...
# ...
